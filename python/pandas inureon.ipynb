# %% [markdown]
# ### Q1. How do you load a CSV file into a Pandas DataFrame?

# %%
import pandas as pd

# %%
dfr = pd.read_csv("data.csv")

# %%
dfr
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# ### Q2. How do you check the data type of a column in a Pandas DataFrame?

# %%
dfr.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %% [markdown]
# ### Q3. How do you select rows from a Pandas DataFrame based on a condition?

# %%
dfr[2:4]
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 2           0.1096            0.1599          0.1974               0.1279
# 3           0.1425            0.2839          0.2414               0.1052
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
#
#    fractal_dimension_worst  Unnamed: 32
# ...

# %%
dfr[2:4][['id','diagnosis','radius_mean','texture_mean','perimeter_mean','area_mean']]
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1

# %%
dfr.iloc[1:6]
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
# 5          0.12780           0.17000          0.1578              0.08089
#
# ...

# %%
dfr.iloc[1:10,0:5]
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean
# 1    842517         M        20.57         17.77          132.90
# 2  84300903         M        19.69         21.25          130.00
# 3  84348301         M        11.42         20.38           77.58
# 4  84358402         M        20.29         14.34          135.10
# 5    843786         M        12.45         15.70           82.57
# 6    844359         M        18.25         19.98          119.60
# 7  84458202         M        13.71         20.83           90.20
# 8    844981         M        13.00         21.82           87.50
# 9  84501001         M        12.46         24.04           83.97

# %%
dfr.loc[1:10,['id','diagnosis','radius_mean','texture_mean','perimeter_mean']]
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean
# 1     842517         M        20.57         17.77          132.90
# 2   84300903         M        19.69         21.25          130.00
# 3   84348301         M        11.42         20.38           77.58
# 4   84358402         M        20.29         14.34          135.10
# 5     843786         M        12.45         15.70           82.57
# 6     844359         M        18.25         19.98          119.60
# 7   84458202         M        13.71         20.83           90.20
# 8     844981         M        13.00         21.82           87.50
# 9   84501001         M        12.46         24.04           83.97
# 10    845636         M        16.02         23.24          102.70

# %% [markdown]
# ### Q4. How do you rename columns in a Pandas DataFrame?

# %%
dfr.rename(columns={'id':'ID'},inplace=True)

# %%
dfr.columns
# Out:
# Index(['ID', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
dfr.count()
# Out:
# ID                         569
# diagnosis                  569
# radius_mean                569
# texture_mean               569
# perimeter_mean             569
# area_mean                  569
# smoothness_mean            569
# compactness_mean           569
# concavity_mean             569
# concave points_mean        569
# symmetry_mean              569
# fractal_dimension_mean     569
# radius_se                  569
# texture_se                 569
# perimeter_se               569
# area_se                    569
# smoothness_se              569
# compactness_se             569
# concavity_se               569
# concave points_se          569
# symmetry_se                569
# fractal_dimension_se       569
# radius_worst               569
# texture_worst              569
# perimeter_worst            569
# area_worst                 569
# smoothness_worst           569
# compactness_worst          569
# concavity_worst            569
# concave points_worst       569
# ...

# %%
dff=dfr

# %%
dff.set_axis(["a","b","c","d","e","f","g","h","i", 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst','concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst'],axis='columns', inplace=True)

# %%
dff.head(5)
# Out:
#           a  b      c      d       e       f        g        h       i  \
# 0    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#    radius_se  ...  smoothness_worst  compactness_worst  concavity_worst  \
# 0    0.14710  ...             17.33             184.60           2019.0
# 1    0.07017  ...             23.41             158.80           1956.0
# 2    0.12790  ...             25.53             152.50           1709.0
# 3    0.10520  ...             26.50              98.87            567.7
# 4    0.10430  ...             16.67             152.20           1575.0
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst  \
# ...

# %% [markdown]
# ### Q5. How do you drop columns in a Pandas DataFrame?

# %%
dfr.head()
# Out:
#           a  b      c      d       e       f        g        h       i  \
# 0    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#    radius_se  ...  smoothness_worst  compactness_worst  concavity_worst  \
# 0    0.14710  ...             17.33             184.60           2019.0
# 1    0.07017  ...             23.41             158.80           1956.0
# 2    0.12790  ...             25.53             152.50           1709.0
# 3    0.10520  ...             26.50              98.87            567.7
# 4    0.10430  ...             16.67             152.20           1575.0
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst  \
# ...

# %%
dfr.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'radius_se', 'texture_se',
#        'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se',
#        'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'concavity_worst',
#        'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
dfr.drop(['a'],axis=1)
# Out:
#      b      c      d       e       f        g        h        i  radius_se  \
# 0    M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010    0.14710
# 1    M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690    0.07017
# 2    M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740    0.12790
# 3    M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140    0.10520
# 4    M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800    0.10430
# ..  ..    ...    ...     ...     ...      ...      ...      ...        ...
# 564  M  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390    0.13890
# 565  M  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400    0.09791
# 566  M  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251    0.05302
# 567  M  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140    0.15200
# 568  B   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000    0.00000
#
# ...

# %%
dfr=dt

# %%
dt.head(5)
# Out:
#           a  b      c      d       e       f        g        h       i  \
# 0    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#    radius_se  ...  smoothness_worst  compactness_worst  concavity_worst  \
# 0    0.14710  ...             17.33             184.60           2019.0
# 1    0.07017  ...             23.41             158.80           1956.0
# 2    0.12790  ...             25.53             152.50           1709.0
# 3    0.10520  ...             26.50              98.87            567.7
# 4    0.10430  ...             16.67             152.20           1575.0
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst  \
# ...

# %% [markdown]
# ### Q6. How do you find the unique values in a column of a Pandas DataFrame?

# %%
unique_val = dt.nunique()

# %%
print(unique_val)
# Out:
# a                          569
# b                            2
# c                          456
# d                          479
# e                          522
# f                          539
# g                          474
# h                          537
# i                          537
# radius_se                  542
# texture_se                 432
# perimeter_se               499
# area_se                    540
# smoothness_se              519
# compactness_se             533
# concavity_se               528
# concave points_se          547
# symmetry_se                541
# fractal_dimension_se       533
# radius_worst               507
# texture_worst              498
# perimeter_worst            545
# area_worst                 457
# smoothness_worst           511
# compactness_worst          514
# concavity_worst            544
# concave points_worst       411
# symmetry_worst             529
# fractal_dimension_worst    539
# concavity_worst            492
# ...

# %% [markdown]
# ### Q7. How do you find the number of missing values in each column of a Pandas DataFrame?

# %%
dt.isnull().sum()
# Out:
# a                          0
# b                          0
# c                          0
# d                          0
# e                          0
# f                          0
# g                          0
# h                          0
# i                          0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# ...

# %% [markdown]
# ### Q8. How do you fill missing values in a Pandas DataFrame with a specific value?

# %%
dt.fillna(dt.mean(numeric_only=True).round(1), inplace=True)

dt.fillna(dt.median(numeric_only=True).round(1), inplace=True)

print(dt)
# Out:
#             a  b      c      d       e       f        g        h        i  \
# 0      842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010
# 1      842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690
# 2    84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740
# 3    84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140
# 4    84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800
# ..        ... ..    ...    ...     ...     ...      ...      ...      ...
# 564    926424  M  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390
# 565    926682  M  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400
# 566    926954  M  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251
# 567    927241  M  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140
# 568     92751  B   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000
#
#      radius_se  ...  smoothness_worst  compactness_worst  concavity_worst  \
# ...

# %%
dt.fillna(method='ffill', inplace=True)
dt.fillna(method='bfill', inplace=True)

# %%
dt.interpolate(method ='linear', limit_direction ='backward', inplace=True)
dt.interpolate(method ='linear', limit_direction ='forward', inplace=True)

# %%
print(dt)
# Out:
#             a  b      c      d       e       f        g        h        i  \
# 0      842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010
# 1      842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690
# 2    84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740
# 3    84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140
# 4    84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800
# ..        ... ..    ...    ...     ...     ...      ...      ...      ...
# 564    926424  M  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390
# 565    926682  M  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400
# 566    926954  M  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251
# 567    927241  M  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140
# 568     92751  B   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000
#
#      radius_se  ...  smoothness_worst  compactness_worst  concavity_worst  \
# ...

# %% [markdown]
# ### Q9. How do you concatenate two Pandas DataFrames?

# %%
vertical_concat = pd.concat([dt, dt], axis=0)

horizontal_concat = pd.concat([dfr, dt], axis=1)
 
display(horizontal_concat,vertical_concat)
# Out:
#             a  b      c      d       e       f        g        h        i  \
# 0      842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010
# 1      842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690
# 2    84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740
# 3    84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140
# 4    84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800
# ..        ... ..    ...    ...     ...     ...      ...      ...      ...
# 564    926424  M  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390
# 565    926682  M  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400
# 566    926954  M  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251
# 567    927241  M  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140
# 568     92751  B   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000
#
#      radius_se  ...  smoothness_worst  compactness_worst  concavity_worst  \
# ...

# %% [markdown]
# ### Q10. How do you merge two Pandas DataFrames on a specific column?

# %%
dr= pd.read_csv("naive.csv")

# %%
dr.merge(dr[['id','diagnosis']])
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# ### Q12. How do you pivot a Pandas DataFrame?

# %%
pivot = dr.pivot_table(index =['id'],
                       values =['radius_mean'],
                       aggfunc ='sum')
print(pivot)
# Out:
#            radius_mean
# id
# 8670             15.46
# 8913             12.89
# 8915             14.96
# 9047             12.94
# 85715            13.17
# ...                ...
# 911157302        21.10
# 911296201        17.08
# 911296202        27.42
# 911320501        11.60
# 911320502        13.17
#
# [569 rows x 1 columns]

# %% [markdown]
# ### Q13. How do you change the data type of a column in a Pandas DataFrame?

# %% [markdown]
# DataFrame.astype() method is used to cast pandas object to a specified dtype. This function also provides the capability to convert any suitable existing column to a categorical type.

# %%
convert_dict = {'id': int,
                'radius_mean': str
                }
 
dr = dr.astype(convert_dict)
print(dr.dtypes)
# Out:
# id                           int32
# diagnosis                   object
# radius_mean                 object
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %% [markdown]
# ### Q14. How do you sort a Pandas DataFrame by a specific column?

# %%
rslt_df = dr.sort_index(ascending = False,axis = 1)

rslt_df
# Out:
#      texture_worst  texture_se  texture_mean  symmetry_worst  symmetry_se  \
# 0            17.33      0.9053         10.38          0.4601      0.03003
# 1            23.41      0.7339         17.77          0.2750      0.01389
# 2            25.53      0.7869         21.25          0.3613      0.02250
# 3            26.50      1.1560         20.38          0.6638      0.05963
# 4            16.67      0.7813         14.34          0.2364      0.01756
# ..             ...         ...           ...             ...          ...
# 564          26.40      1.2560         22.39          0.2060      0.01114
# 565          38.25      2.4630         28.25          0.2572      0.01898
# 566          34.12      1.0750         28.08          0.2218      0.01318
# 567          39.42      1.5950         29.33          0.4087      0.02324
# 568          30.37      1.4280         24.54          0.2871      0.02676
#
#      symmetry_mean  smoothness_worst  smoothness_se  smoothness_mean  \
# ...

# %% [markdown]
#  ### 22 How do you sort a DataFrame by a specific column?

# %%
dr.sort_values(by=['diagnosis'])
# Out:
#           id diagnosis radius_mean  texture_mean  perimeter_mean  area_mean  \
# 284  8912284         B       12.89         15.70           84.08      516.6
# 371  9012568         B       15.19         13.21           97.65      711.8
# 367  9011495         B       12.21         18.02           78.31      458.4
# 364  9010877         B        13.4         16.95           85.48      552.4
# 363  9010872         B        16.5         18.29          106.60      838.1
# ..       ...       ...         ...           ...             ...        ...
# 146   869691         M        11.8         16.58           78.99      432.0
# 379  9013838         M       11.08         18.83           73.30      361.6
# 141   869104         M       16.11         18.05          105.10      813.0
# 138   868826         M       14.95         17.57           96.85      678.1
# 0     842302         M       17.99         10.38          122.80     1001.0
#
# ...

# %%
dr.sort_values(by=['id', 'diagnosis'],
               ascending=[False, True])
# Out:
#             id diagnosis radius_mean  texture_mean  perimeter_mean  area_mean  \
# 464  911320502         B       13.17         18.22           84.28      537.3
# 463  911320501         B        11.6         18.36           73.88      412.7
# 461  911296202         M       27.42         26.27          186.90     2501.0
# 460  911296201         M       17.08         27.15          111.20      930.9
# 449  911157302         M        21.1         20.52          138.10     1384.0
# ..         ...       ...         ...           ...             ...        ...
# 47       85715         M       13.17         18.66           85.98      534.6
# 403       9047         B       12.94         16.17           83.18      507.6
# 291       8915         B       14.96         19.10           97.03      687.3
# 287       8913         B       12.89         13.12           81.89      515.9
# 131       8670         M       15.46         19.48          101.70      748.9
#
# ...

# %% [markdown]
# ### Q15. How do you create a copy of a Pandas DataFrame?

# %%
df1=dr.copy()

# %%
df1
# Out:
#            id diagnosis radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.99         10.38          122.80     1001.0
# 1      842517         M       20.57         17.77          132.90     1326.0
# 2    84300903         M       19.69         21.25          130.00     1203.0
# 3    84348301         M       11.42         20.38           77.58      386.1
# 4    84358402         M       20.29         14.34          135.10     1297.0
# ..        ...       ...         ...           ...             ...        ...
# 564    926424         M       21.56         22.39          142.00     1479.0
# 565    926682         M       20.13         28.25          131.20     1261.0
# 566    926954         M        16.6         28.08          108.30      858.1
# 567    927241         M        20.6         29.33          140.10     1265.0
# 568     92751         B        7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# ### Q16. How do you filter rows of a Pandas DataFrame by multiple conditions?

# %%
dataFrame = pd.DataFrame({'Name': [' RACHEL  ', ' MONICA  ', ' PHOEBE  ',
                                   '  ROSS    ', 'CHANDLER', ' JOEY    '],
                           
                          'Age': [30, 35, 37, 33, 34, 30],
                           
                          'Salary': [100000, 93000, 88000, 120000, 94000, 95000],
                           
                          'JOB': ['DESIGNER', 'CHEF', 'MASUS', 'PALENTOLOGY',
                                  'IT', 'ARTIST']})
# filter dataframe
display(dataFrame.loc[(dataFrame['Salary']>=1000) & (dataFrame['Age']< 40) & (dataFrame['JOB'].str.startswith('D')),
                    ['Name','JOB']])
# Out:
#         Name       JOB
# 0   RACHEL    DESIGNER

# %% [markdown]
# ### Q17. How do you calculate the mean of a column in a Pandas DataFrame?

# %%
df1.mean()
# Out:
# C:\Users\jaanu\AppData\Local\Temp\ipykernel_13052\2053335143.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean()
# id                         3.037183e+07
# texture_mean               1.928965e+01
# perimeter_mean             9.196903e+01
# area_mean                  6.548891e+02
# smoothness_mean            9.636028e-02
# compactness_mean           1.043410e-01
# concavity_mean             8.879932e-02
# concave points_mean        4.891915e-02
# symmetry_mean              1.811619e-01
# fractal_dimension_mean     6.279761e-02
# radius_se                  4.051721e-01
# texture_se                 1.216853e+00
# perimeter_se               2.866059e+00
# area_se                    4.033708e+01
# smoothness_se              7.040979e-03
# compactness_se             2.547814e-02
# ...

# %% [markdown]
# ### Q18. How do you calculate the standard deviation of a column in a Pandas DataFrame?

# %%
dt.std()
# Out:
# C:\Users\jaanu\AppData\Local\Temp\ipykernel_13052\2572274960.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dt.std()
# a                          1.250206e+08
# c                          3.524049e+00
# d                          4.301036e+00
# e                          2.429898e+01
# f                          3.519141e+02
# g                          1.406413e-02
# h                          5.281276e-02
# i                          7.971981e-02
# radius_se                  3.880284e-02
# texture_se                 2.741428e-02
# perimeter_se               7.060363e-03
# area_se                    2.773127e-01
# smoothness_se              5.516484e-01
# compactness_se             2.021855e+00
# concavity_se               4.549101e+01
# concave points_se          3.002518e-03
# ...

# %% [markdown]
# ### Q19. How do you calculate the correlation between two columns in a Pandas DataFrame?

# %%
dt=dfr.copy()

# %%
dt
# Out:
#             a  b      c      d       e       f        g        h        i  \
# 0      842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010
# 1      842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690
# 2    84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740
# 3    84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140
# 4    84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800
# ..        ... ..    ...    ...     ...     ...      ...      ...      ...
# 564    926424  M  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390
# 565    926682  M  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400
# 566    926954  M  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251
# 567    927241  M  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140
# 568     92751  B   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000
#
#      radius_se  ...  smoothness_worst  compactness_worst  concavity_worst  \
# ...

# %%
print(dt['c'].corr(dt['d']))
# Out:
# 0.323781890927733

# %% [markdown]
# ### Q24. How do you remove duplicates from a DataFrame?

# %%
df2=df1.drop_duplicates()

# %%
df2
# Out:
#            id diagnosis radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.99         10.38          122.80     1001.0
# 1      842517         M       20.57         17.77          132.90     1326.0
# 2    84300903         M       19.69         21.25          130.00     1203.0
# 3    84348301         M       11.42         20.38           77.58      386.1
# 4    84358402         M       20.29         14.34          135.10     1297.0
# ..        ...       ...         ...           ...             ...        ...
# 564    926424         M       21.56         22.39          142.00     1479.0
# 565    926682         M       20.13         28.25          131.20     1261.0
# 566    926954         M        16.6         28.08          108.30      858.1
# 567    927241         M        20.6         29.33          140.10     1265.0
# 568     92751         B        7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# ### Q20. How do you select specific columns in a DataFrame using their labels?

# %% [markdown]
# The .loc[] function selects the data by labels of rows or columns. It can select a subset of rows and columns. There are many ways to use this function.

# %%
employees = [('Stuti', 28, 'Varanasi', 20000),
            ('Saumya', 32, 'Delhi', 25000),
            ('Aaditya', 25, 'Mumbai', 40000),
            ('Saumya', 32, 'Delhi', 35000),
            ('Saumya', 32, 'Delhi', 30000),
            ('Saumya', 32, 'Mumbai', 20000),
            ('Aaditya', 40, 'Dehradun', 24000),
            ('Seema', 32, 'Delhi', 70000)
            ]
 
df = pd.DataFrame(employees,
                columns =['Name', 'Age',
                'City', 'Salary'])

df.set_index("Name", inplace = True)
 

result = df.loc["Stuti"]

result
# Out:
# Age             28
# City      Varanasi
# Salary       20000
# Name: Stuti, dtype: object

# %% [markdown]
# ### Q21. How do you select specific rows in a DataFrame using their indexes?

# %% [markdown]
#  Index You can select columns by index from the dataframe by using the iloc attribute of the dataframe. Use the below snippet to select only the column at index position 0.

# %%
df2.iloc[0:5,1:5]
# Out:
#   diagnosis radius_mean  texture_mean  perimeter_mean
# 0         M       17.99         10.38          122.80
# 1         M       20.57         17.77          132.90
# 2         M       19.69         21.25          130.00
# 3         M       11.42         20.38           77.58
# 4         M       20.29         14.34          135.10
